# %%
import pandas as pd
import gzip

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF('reviews_Amazon_Instant_Video_5.json.gz')

# %%
We start with the Amazon_Instant_Video (5-core) data because it is the smallest 
we can put them in a pandas dataframe

# %%
df
# Out:
#            reviewerID        asin  \
# 0      A11N155CW1UV02  B000H00VBQ
# 1      A3BC8O2KCL29V2  B000H00VBQ
# 2       A60D5HQFOTSOM  B000H00VBQ
# 3      A1RJPIGRSNX4PW  B000H00VBQ
# 4      A16XRPF40679KG  B000H00VBQ
# 5      A1POFVVXUZR3IQ  B000H00VBQ
# 6      A1PG2VV4W1WRPL  B000H0X79O
# 7       ATASGS8HZHGIB  B000H0X79O
# 8      A3RXD7Z44T9DHW  B000H0X79O
# 9       AUX8EUBNTHIIU  B000H0X79O
# 10      AXM3GQLD0CHIL  B000H0X79O
# 11     A398QSASJOIKA6  B000H29TXU
# 12     A2U61O0KWJH3MM  B000H29TXU
# 13     A2LSZFEFTDRDIJ  B000H29TXU
# 14     A39F2EW27YYUDM  B000H29TXU
# 15      AO1Z63O9CTT95  B000H29TXU
# 16     A1378ZJMWCTVT3  B000H2DMME
# 17     A2JE0JYIZL5NU4  B000H2DMME
# 18     A2LSZFEFTDRDIJ  B000H2DMME
# 19     A3RXD7Z44T9DHW  B000H2DMME
# 20      AAWV26JJ1SGS0  B000H2DMME
# 21      AS2AMJR6JJZSS  B000H2DMME
# 22      AXM3GQLD0CHIL  B000H2DMME
# 23      AYCGI5JRRISTJ  B000H2DMME
# 24     A1939G7K0LLQ8P  B000H2DMME
# 25     A2LUBUMIQEVWD3  B000H2DMME
# ...

# %%
df.set_index('asin')
# Out:
#                 reviewerID                                 reviewerName  \
# asin
# B000H00VBQ  A11N155CW1UV02                                     AdrianaM
# B000H00VBQ  A3BC8O2KCL29V2                                      Carol T
# B000H00VBQ   A60D5HQFOTSOM               Daniel Cooper "dancoopermedia"
# B000H00VBQ  A1RJPIGRSNX4PW                               J. Kaplan "JJ"
# B000H00VBQ  A16XRPF40679KG                                Michael Dobey
# B000H00VBQ  A1POFVVXUZR3IQ                                      Z Hayes
# B000H0X79O  A1PG2VV4W1WRPL               Jimmy C. Saunders "Papa Smurf"
# B000H0X79O   ATASGS8HZHGIB                                      JohnnyC
# B000H0X79O  A3RXD7Z44T9DHW                                       Kansas
# B000H0X79O   AUX8EUBNTHIIU                          Louis V. Borsellino
# B000H0X79O   AXM3GQLD0CHIL                                    Ray Shiva
# B000H29TXU  A398QSASJOIKA6                              Amazon Customer
# ...

# %%
from datetime import datetime
from datetime import date, time
from dateutil.parser import parse
df.reviewTime[0]
# Out:
# '05 3, 2014'

# %%
parse(df.reviewTime.iloc[0]) # year,month,day,hour,minute
# Out:
# datetime.datetime(2014, 5, 3, 0, 0)

# %%
import pandas as pd
pd.to_datetime(df.reviewTime)
# Out:
# 0       2014-05-03
# 1       2012-09-03
# 2       2013-10-16
# 3       2013-10-30
# 4       2009-02-11
# 5       2011-10-11
# 6       2013-10-15
# 7       2013-12-29
# 8       2014-02-26
# 9       2014-04-02
# 10      2014-02-07
# 11      2014-02-06
# 12      2013-09-05
# 13      2013-06-14
# 14      2014-04-29
# 15      2014-03-06
# 16      2014-01-09
# 17      2014-05-18
# 18      2013-02-10
# 19      2014-03-06
# 20      2014-02-13
# 21      2014-02-08
# 22      2013-04-24
# 23      2013-03-09
# 24      2012-04-09
# 25      2014-01-02
# 26      2014-03-22
# 27      2012-10-19
# 28      2014-03-22
# 29      2013-07-08
#            ...
# 37096   2014-07-14
# 37097   2014-07-23
# 37098   2014-07-22
# 37099   2014-07-17
# 37100   2014-07-13
# 37101   2014-07-17
# 37102   2014-07-21
# 37103   2014-07-09
# 37104   2014-07-05
# 37105   2014-07-07
# 37106   2014-07-14
# 37107   2014-07-14
# 37108   2014-07-05
# 37109   2014-07-04
# 37110   2014-07-14
# 37111   2014-07-14
# ...

# %%
frequency=df.groupby('reviewTime').count()
frequency
# Out:
#              reviewerID  asin  reviewerName  helpful  reviewText  overall  \
# reviewTime
# 01 1, 2007            1     1             1        1           1        1
# 01 1, 2010            1     1             1        1           1        1
# 01 1, 2012            4     4             4        4           4        4
# 01 1, 2013           14    14            13       14          14       14
# 01 1, 2014           54    54            54       54          54       54
# 01 10, 2010           1     1             1        1           1        1
# 01 10, 2011           1     1             1        1           1        1
# 01 10, 2012           2     2             2        2           2        2
# 01 10, 2013          24    24            24       24          24       24
# 01 10, 2014          49    49            49       49          49       49
# 01 11, 2008           2     2             2        2           2        2
# ...

# %%
# %pylab inline
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('notebook')
import plotly.plotly as py
import plotly.graph_objs as go
py.iplot(df.groupby('reviewTime').count().asin)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-e676bf8ab5a7> in <module>()
#       6 import seaborn as sns
#       7 sns.set_context('notebook')
# ----> 8 import plotly.plotly as py
#       9 import plotly.graph_objs as go
#      10 py.iplot(df.groupby('reviewTime').count().asin)
#
# ModuleNotFoundError: No module named 'plotly'

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-54d658d4291a> in <module>()
# ----> 1 plot(parse(str(frequency.index)),frequency.asin)
#
# /Users/sonia/anaconda/lib/python3.6/site-packages/dateutil/parser.py in parse(timestr, parserinfo, **kwargs)
#    1166         return parser(parserinfo).parse(timestr, **kwargs)
#    1167     else:
# -> 1168         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1169
#    1170
#
# /Users/sonia/anaconda/lib/python3.6/site-packages/dateutil/parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     557
#     558         if res is None:
# --> 559             raise ValueError("Unknown string format")
#     560
#     561         if len(res) == 0:
#
# ValueError: Unknown string format
